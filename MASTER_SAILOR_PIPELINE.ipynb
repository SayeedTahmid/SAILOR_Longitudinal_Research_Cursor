# %% [markdown]
# # MASTER SAILOR PIPELINE
#
# Primary implementation: `cursor_primary`
# Locked target: `CL / enhancing_t1wc`
# Phase 1 sections are CPU-only. All resource measurements remain `UNMEASURED` until profiled on real data.

# %%
# Section 01 — Environment & hardware
from sailor.sections import run_phase1_section
section_01 = run_phase1_section(1)
section_01

# %%
# Section 02 — Project configuration
section_02 = run_phase1_section(2)
section_02

# %%
# Section 03 — Provenance / dataset audit
section_03 = run_phase1_section(3)
section_03

# %%
# Section 04 — Canonical manifest creation
section_04 = run_phase1_section(4)
section_04

# %%
# Section 05 — Patient / session statistics
section_05 = run_phase1_section(5)
section_05

# %%
# Section 06 — CL mask validation (G1)
section_06 = run_phase1_section(6)
section_06

# %%
# Section 07 — Raw ↔ MNI mapping (G8)
section_07 = run_phase1_section(7)
section_07

# %%
# Section 08 — Δt validation (G7)
section_08 = run_phase1_section(8)
section_08

# %%
# Section 09 — Dose-map validation
section_09 = run_phase1_section(9)
section_09

# %%
# Section 10 — Deterministic preprocessing dry run / longitudinal windows
from sailor.sections import run_phase2_section
section_10 = run_phase2_section(10)
section_10

# %%
# Section 11 — Frozen patient-level nested CV
section_11 = run_phase2_section(11)
section_11

# %%
# Section 12 — Full Stage-2 leakage guard (G5)
section_12 = run_phase2_section(12)
section_12

# %%
# Section 13 — Phase 2 data QC
section_13 = run_phase2_section(13)
section_13
